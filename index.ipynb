# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
df.sort_values(""ascending=False)
# Out:
# array(['NQR456W', 'NQRW', 'ACENQRS1237W', 'BDFMNQRW', 'NRW', 'LNQR456W',
#        'JNQRZ6W', 'RNW', 'R1W', 'FJMZ', 'JZ', 'JZ456', 'ACJZ2345', 'BQ',
#        'S', 'S2345', 'BQS', 'Q', 'R2345', 'R', 'BDNQR', 'BDNQR2345',
#        'DFGMNR', 'DNR', 'N', 'ND', 'D', 'DFNQ', 'FQ', 'ACEL', 'FLM123',
#        'L', 'LG', 'LM', 'A', 'E', 'JMZ', 'JM', 'J', 'M', 'AC1', 'C',
#        'ABCD', 'BC', 'ACBD', 'ABCD1', 'CE', 'ACENGRS1237W', 'ACE',
#        'ABCDEFM', 'ACE23', '2345ACJZ', 'AC', 'ACF', 'ACG', 'ACS', 'ACJLZ',
#        'AS', 'BD', 'BD4', 'BDE', 'EM', 'EM6', 'EMG', 'EMR', 'MR', 'EFMR7',
#        'EFMR', 'EF', 'F', 'G', 'GL', 'BDFM', 'BDFM7', 'BDFQ6', 'FG',
#        'EJZ', '6', '1', '1RW', '23', '23ACE', '123', '123FLM', '123ACE',
#        '1237ACENQRSW', '1237ACENQRS', '1ABCD', '1AC', '45', '456JZ',
#        '6DF', '456LNQRW', '4567S', '456NQRW', '456', '245', '4BD', '4',
#        '3', '25', '2', '7BDFM', '7', '7NQW', 'NQW', '7EFMR', '2345R',
# ...

# %%
df_cols = list(df.columns)
df_cols = list(map(lambda col: col.lower(), df_cols))
df_cols[-1] = df_cols[-1].strip()
df_cols
# Out:
# ['c/a',
#  'unit',
#  'scp',
#  'station',
#  'linename',
#  'division',
#  'date',
#  'time',
#  'desc',
#  'entries',
#  'exits']

# %%
new_cols = [col.lower() for col in df.columns]
df.columns = new_cols
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries    exits
# 0  REGULAR  6736067  2283184
# 1  REGULAR  6736087  2283188
# 2  REGULAR  6736105  2283229
# 3  REGULAR  6736180  2283314
# 4  REGULAR  6736349  2283384

# %%
df.columns = df_cols
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries    exits
# 0  REGULAR  6736067  2283184
# 1  REGULAR  6736087  2283188
# 2  REGULAR  6736105  2283229
# 3  REGULAR  6736180  2283314
# 4  REGULAR  6736349  2283384

# %%
whais = df.groupby('date').sum()
whais.head()
# Out:
#                   entries         exits
# date
# 08/25/2018  1115661545514  909142081474
# 08/26/2018  1192306179082  959223750461
# 08/27/2018  1114237052454  911938153513
# 08/28/2018  1143313287046  942230721477
# 08/29/2018  1123655222441  920630864687

# %% [markdown]
# # Change the Index to be the Line Names

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 11 columns):
# c/a         197625 non-null object
# unit        197625 non-null object
# scp         197625 non-null object
# station     197625 non-null object
# linename    197625 non-null object
# division    197625 non-null object
# date        197625 non-null object
# time        197625 non-null object
# desc        197625 non-null object
# entries     197625 non-null int64
# exits       197625 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 16.6+ MB

# %%
df = df.set_index("linename")
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries    exits
# linename
# NQR456W   REGULAR  6736067  2283184
# NQR456W   REGULAR  6736087  2283188
# NQR456W   REGULAR  6736105  2283229
# NQR456W   REGULAR  6736180  2283314
# NQR456W   REGULAR  6736349  2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
#indices = list(range(0,197625))
#df = df.set_index(indices)
#df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 11 columns):
# c/a         197625 non-null object
# unit        197625 non-null object
# scp         197625 non-null object
# station     197625 non-null object
# linename    197625 non-null object
# division    197625 non-null object
# date        197625 non-null object
# time        197625 non-null object
# desc        197625 non-null object
# entries     197625 non-null int64
# exits       197625 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 16.6+ MB

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
#finding how many rows there are for each station:
station_freq = {}
for station_name in list(df.station):
    station_freq[station_name]=station_freq.get(station_name,0) + 1

# %%
line_counts = []
num_lines_dict = {}

for station_name in list(df.station):
    df.#take only the rows from station_freq[station_name]
    #and then get the linenames and then take a set of them
    #and do len(of the set)
    #and add that number to line_counts once each for station_freq
    line_counts.append(station_freq[station_name])
    num_lines_dict = {}
# Out:
# 2229

# %%
#df = df.set_index(["station","linename"])

# %%
#line_counts = num_lines_dict.values()
#df.insert(1,"Num_Lines",line_counts).head()

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.strip()
    cleaned = col_name.title()
    #Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['C/A', 'Unit', 'Scp', 'Station', 'Linename', 'Division', 'Date', 'Time',
#        'Desc', 'Entries', 'Exits'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here

# %% [markdown]
# # Drop a couple of columns

# %%
df.drop(columns="Division").head()
# Out:
#     C/A  Unit       Scp Station Linename        Date      Time     Desc  \
# 0  A002  R051  02-00-00   59 ST  NQR456W  08/25/2018  00:00:00  REGULAR
# 1  A002  R051  02-00-00   59 ST  NQR456W  08/25/2018  04:00:00  REGULAR
# 2  A002  R051  02-00-00   59 ST  NQR456W  08/25/2018  08:00:00  REGULAR
# 3  A002  R051  02-00-00   59 ST  NQR456W  08/25/2018  12:00:00  REGULAR
# 4  A002  R051  02-00-00   59 ST  NQR456W  08/25/2018  16:00:00  REGULAR
#
#    Entries    Exits
# 0  6736067  2283184
# 1  6736087  2283188
# 2  6736105  2283229
# 3  6736180  2283314
# 4  6736349  2283384

# %%
df.head()
# Out:
#     C/A  Unit       Scp Station Linename Division        Date      Time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       Desc  Entries    Exits
# 0  REGULAR  6736067  2283184
# 1  REGULAR  6736087  2283188
# 2  REGULAR  6736105  2283229
# 3  REGULAR  6736180  2283314
# 4  REGULAR  6736349  2283384
